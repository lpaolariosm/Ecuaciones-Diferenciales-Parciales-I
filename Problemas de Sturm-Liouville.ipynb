# %% [markdown]
# <a href="https://colab.research.google.com/github/lpaolariosm/Ecuaciones-Diferenciales-Parciales-I/blob/main/Problemas%20de%20Sturm-Liouville.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # <span style="color:orange;">Problemas de Sturm-Liouville con el uso de  SymPy (Python)</span>

# %% [markdown]
# ## Resolver la ecuación diferencial
#
# $X''+ λX=0 \quad X(0)=X(1)=0$

# %% [markdown]
# Importamos la librerias necesarias

# %%
from sympy import *
import sympy as sp
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# Defininimos las variables

# %%
x = sp.symbols('x')
X = sp.Function('X')
k = sp.pi**2  # Valor ejemplo de k
C1, C2 = sp.symbols('C1 C2')

# %% [markdown]
# EDO: $X'' + kX = 0$

# %%
ode1= sp.Eq(X(x).diff(x, 2) + k*X(x), 0)

# %% [markdown]
# Solucion general

# %%
sol1 = sp.dsolve(ode1, X(x))
Xsol1 = sol1.rhs
sol1
# Out:
# Eq(X(x), C1*sin(pi*x) + C2*cos(pi*x))

# %% [markdown]
# Aplicar condiciones: X(0) = 0, X(1) = 0

# %%
conds1 = [
    Xsol1.subs(x, 0),
    Xsol1.subs(x, 1)
]
sol_c1 = sp.solve(conds1, (C1, C2))
Xsol1 = Xsol1 = Xsol1.subs(sol_c1).subs(C1, 1) # C2 es la constante libre

Xsol1
# Out:
# sin(pi*x)

# %% [markdown]
# Convertir a función numérica

# %%
func1 = sp.lambdify(x, Xsol1, 'numpy')
xx = np.linspace(0, 1, 200)
yy1 = func1(xx)

# %% [markdown]
# graficar

# %%
plt.plot(xx, yy1, 'r', label='Problema 1')
plt.xlabel('x')
plt.ylabel('X(x)')
plt.title('Solución del Problema 1: X(0)=0, X(1)=0')
plt.grid(True)
plt.legend()
plt.show()

# %% [markdown]
# ## Resolver la ecuación diferencial
#
# $X''+ λX=0 \quad X'(0)=X'(1)=0$

# %%
from sympy import *
import sympy as sp
import numpy as np
import matplotlib.pyplot as plt

# %%
x = sp.symbols('x')
X = sp.Function('X')
k = sp.pi**2  # Valor ejemplo de k
C1, C2 = sp.symbols('C1 C2')

# %%
ode2 =  sp.Eq(X(x).diff(x, 2) + k*X(x), 0)

# %% [markdown]
# Solución general

# %%
sol2 =  sp.dsolve(ode2, X(x))
Xsol2 = sol2.rhs
dXsol2 = Xsol2.diff(x)
sol2
# Out:
# Eq(X(x), C1*sin(pi*x) + C2*cos(pi*x))

# %% [markdown]
#  Aplicar condiciones: X'(0) = 0, X'(1) = 0

# %%
const2= [
    dXsol2.subs(x, 0),  # X'(0) = 0
    dXsol2.subs(x, 1)   # X'(1) = 0
]
sol_c2 = sp.solve(const2, (C1, C2)) # Changed 'conds2' to 'const2'
# Sustituir soluciones y asignar valor a la constante restante
Xsol2 = Xsol2.subs(sol_c2).subs(C2, 1)  # C1 es la constante libre
Xsol2
# Out:
# cos(pi*x)

# %%
func2 = sp.lambdify(x, Xsol2, 'numpy')
xx = np.linspace(0, 2, 200)
yy2 = func2(xx)

# %%
# Graficar
plt.plot(xx, yy2, 'b', label='Problema 2')
plt.xlabel('x')
plt.ylabel('X(x)')
plt.title("Solución del Problema 2: X'(0)=0, X'(1)=0")
plt.grid(True)
plt.legend()
plt.show()
