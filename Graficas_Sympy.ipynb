# %% [markdown]
# <a href="https://colab.research.google.com/github/lpaolariosm/Ecuaciones-Diferenciales-Parciales-I/blob/main/Graficas_Sympy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sympy import *

# %% [markdown]
# **Importa todas las funciones y clases de la biblioteca SymPy a la seción interactiva de Python**

# %%
x=symbols('x')

# %% [markdown]
# **Crea multiples instancias, define clases y funciones separadas para crear objetos**

# %%
x**2+5
# Out:
# x**2 + 5

# %%
c1=plotting.plot(x*x)

# %% [markdown]
# Sirve para graficar las funciones dadas, sólo en una dimención

# %%
cl=plotting.plot(x*x,show=False)
c2=plotting.plot(x**3,show=False)

# %% [markdown]
# **Sirve para crear el objeto de la gráfica sin mostrarlo.**

# %%
c1 #Indica qué es y en qué espacio de memoria está

# %%
c1.append(c2[0]) #Anida las gráficas sin los ejes

# %%
c1

# %%
c1.show()

# %% [markdown]
# **Ahora se muestra la gráfica.**

# %%
c1.extend(c2)

# %% [markdown]
# **Sirve para cuando hay dos comandos y se quieren combinar en uno solo.**

# %%
c1.show()

# %% [markdown]
# **Muestra la gráfica de ambos comandos.**

# %%
c2.show()

# %% [markdown]
# **Muestra la gráfica del comando c2.**

# %%
from sympy.plotting import plot

# %% [markdown]
# **Importa la función plot que se usa para graficar funciones matematicas simbólica**

# %%
plot(x**2)

# %% [markdown]
# **Genera una gráfica**

# %%
plot(x**2,(x,-1,1))

# %% [markdown]
# **Geenera una gráfica tomando en cuenta los puntos limites de -1 y 1**

# %%
plot(exp(x))
#plot(exp(x),(x,0,2))

# %% [markdown]
# **Grafica la función $e^x$**

# %%
plot(x,x**2,x**3, (x,-2,2))

# %% [markdown]
# **Grafica las tres funciones dadas, $x, x^2, x^3$ en los limites de -2 y 2.**

# %%
plot(x**2,adaptative=False,nb_of_points=10) #Revisar

# %% [markdown]
# **Grafica la función $x^2$ con un número fijo de puntos.**
# ***adaptative=False:*** desactiva el refinamiento automatico.
# ***nb_of_points=x:*** Indica los puntos para dibujar la gráfica

# %% [markdown]
# ### Curvas parametrizadas

# %%
from sympy import plot_parametric

# %% [markdown]
# **Se usa para graficar curvas parametricas donde *x* & *y* dependen de un parámetro *t*, es util para graficar círculos, espirales, trayectorias, etc**

# %%
s=symbols('s')

# %% [markdown]
# **Crea multiples instancias, define clases y funciones separadas para crear objetos**

# %%
plot_parametric((cos(s)),sin(s))

# %% [markdown]
# Dibuja la circunferencia unitaria

# %%
plot_parametric((cos(s),sin(s)),(s,s**2),(s,-4,4))

# %%
c2[0].line_color='green'

# %%
c2.show()

# %% [markdown]
# ### Graficas 3D

# %%
from sympy.plotting import plot3d

# %%
x,y=symbols('x y')

# %%
plot3d(x*y)

# %%
plot3d(x*y, (x,-5,5),(y,-5,5))

# %%
plot3d(x*y, -x*y, (x,-5,5),(y,-5,5))

# %%
plot3d((x**2 + y**2, (x,-5,5),(y,-5,5)),(x*y,(x,-3,3),(y,-3,3)))

# %%
from sympy.plotting import plot3d_parametric_line

# %%
plot3d_parametric_line(cos(s),sin(s),s)

# %%
plot3d_parametric_line((cos(s),sin(s),s,(s,-5,5)),(sin(s),s**2,s,(s,-5,5)))

# %%
from sympy.plotting import plot3d_parametric_surface

# %%
u, v =symbols('u v')

# %%
plot3d_parametric_surface(cos(u+v),sin(u-v),u-v)

# %%
plot3d_parametric_surface(cos(v)*cos(u),cos(v)*sin(u),sin(v))

# %% [markdown]
# Funciones implícitas

# %%
from sympy import plot_implicit, symbols, Eq, And

# %%
x, y = symbols(' x y')

# %%
p1 = plot_implicit(Eq(x**2 + y**2, 5))

# %%
p6 = plot_implicit(y > x**2)

# %%
p6 = plot_implicit(And(y > x, y > -x))

# %%
#Ejercicio, graficar x^3-xy+y^3
from sympy import *
from sympy.plotting import plot3d

x,y=symbols('x,y')
plot3d(x**3-x*y+y**3,(x, -5, 5), (y, -5, 5))
